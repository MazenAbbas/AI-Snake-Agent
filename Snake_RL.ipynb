# %%
# !pip install numpy pygame
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: pygame in /usr/local/lib/python3.12/dist-packages (2.6.1)

# %%
import pygame
import random
import numpy as np

# Define game constants
SCREEN_WIDTH = 600
SCREEN_HEIGHT = 600
GRID_SIZE = 30
GRID_WIDTH = SCREEN_WIDTH // GRID_SIZE
GRID_HEIGHT = SCREEN_HEIGHT // GRID_SIZE
WHITE = (255, 255, 255)
GREEN = (0, 255, 0)
RED = (255, 0, 0)
BLACK = (0, 0, 0)

# Define the Snake class
class Snake:
    def __init__(self):
        self.body = [(GRID_WIDTH // 2, GRID_HEIGHT // 2)]
        self.direction = (0, 1)
        self.score = 0
        self.food = self.spawn_food()

    def spawn_food(self):
        while True:
            food_pos = (random.randint(0, GRID_WIDTH - 1), random.randint(0, GRID_HEIGHT - 1))
            if food_pos not in self.body:
                return food_pos

    def move(self):
        head_x, head_y = self.body[0]
        dx, dy = self.direction
        new_head = (head_x + dx, head_y + dy)

        self.body.insert(0, new_head)

        if new_head == self.food:
            self.score += 1
            self.food = self.spawn_food()
        else:
            self.body.pop()

    def check_collision(self):
        head = self.body[0]
        # Collision with walls
        if (head[0] < 0 or head[0] >= GRID_WIDTH or
            head[1] < 0 or head[1] >= GRID_HEIGHT):
            return True
        # Collision with its own body
        if head in self.body[1:]:
            return True
        return False

# This part is just for testing the game logic.
# The Reinforcement Learning agent will replace the manual control.
if __name__ == '__main__':
    pygame.init()
    screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
    clock = pygame.time.Clock()

    snake = Snake()

    running = True
    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False
            elif event.type == pygame.KEYDOWN:
                if event.key == pygame.K_UP and snake.direction != (0, 1):
                    snake.direction = (0, -1)
                elif event.key == pygame.K_DOWN and snake.direction != (0, -1):
                    snake.direction = (0, 1)
                elif event.key == pygame.K_LEFT and snake.direction != (1, 0):
                    snake.direction = (-1, 0)
                elif event.key == pygame.K_RIGHT and snake.direction != (-1, 0):
                    snake.direction = (1, 0)

        snake.move()
        if snake.check_collision():
            running = False

        screen.fill(BLACK)
        # Draw the snake
        for x, y in snake.body:
            pygame.draw.rect(screen, GREEN, (x * GRID_SIZE, y * GRID_SIZE, GRID_SIZE, GRID_SIZE))
        # Draw the food
        pygame.draw.rect(screen, RED, (snake.food[0] * GRID_SIZE, snake.food[1] * GRID_SIZE, GRID_SIZE, GRID_SIZE))

        pygame.display.flip()
        clock.tick(10)

    pygame.quit()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.11)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import numpy as np
import random
from collections import deque
import pygame

# Q-Learning parameters
LEARNING_RATE = 0.001
DISCOUNT = 0.99
EPSILON = 0.1  # For exploration vs exploitation

# Define the Agent class
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = DISCOUNT
        self.epsilon = EPSILON
        self.learning_rate = LEARNING_RATE

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)

        # In this simple example, we'll just choose the best action based on
        # a simple heuristic, but for more complex models, we would use a Neural Network
        # For simplicity, we'll implement a basic Q-Learning update rule
        # A full implementation would involve training a deep neural network
        # For our purposes, we'll assume a Q-table is being updated

        # A simple heuristic for choosing the next action
        # This is a temporary stand-in for a real neural network prediction
        actions = [0, 1, 2, 3] # 0:UP, 1:DOWN, 2:LEFT, 3:RIGHT
        return random.choice(actions)

    def replay(self, batch_size):
        # We'll skip the complex replay logic for this simple example
        pass

# This part is just a skeleton for the full implementation.
# A full RL project would involve a deep neural network inside the agent to predict Q-values.
# For this project, we'll focus on the logic of the game itself and how the agent interacts with it.

# %%
import pygame
import random
import numpy as np

# Define game constants
SCREEN_WIDTH = 600
SCREEN_HEIGHT = 600
GRID_SIZE = 30
GRID_WIDTH = SCREEN_WIDTH // GRID_SIZE
GRID_HEIGHT = SCREEN_HEIGHT // GRID_SIZE
WHITE = (255, 255, 255)
GREEN = (0, 255, 0)
RED = (255, 0, 0)
BLACK = (0, 0, 0)

# Define the Snake class (same as before)
class Snake:
    def __init__(self):
        self.body = [(GRID_WIDTH // 2, GRID_HEIGHT // 2)]
        self.direction = (0, 1)
        self.score = 0
        self.food = self.spawn_food()

    def spawn_food(self):
        while True:
            food_pos = (random.randint(0, GRID_WIDTH - 1), random.randint(0, GRID_HEIGHT - 1))
            if food_pos not in self.body:
                return food_pos

    def move(self, action):
        # Convert action (0,1,2,3) to a new direction
        # 0: Up, 1: Down, 2: Left, 3: Right
        if action == 0:
            self.direction = (0, -1)
        elif action == 1:
            self.direction = (0, 1)
        elif action == 2:
            self.direction = (-1, 0)
        elif action == 3:
            self.direction = (1, 0)

        head_x, head_y = self.body[0]
        dx, dy = self.direction
        new_head = (head_x + dx, head_y + dy)

        self.body.insert(0, new_head)

        reward = 0
        done = False

        if new_head == self.food:
            self.score += 1
            reward = 10
            self.food = self.spawn_food()
        else:
            self.body.pop()

        if self.check_collision():
            reward = -10
            done = True

        return reward, done

    def check_collision(self):
        head = self.body[0]
        if (head[0] < 0 or head[0] >= GRID_WIDTH or
            head[1] < 0 or head[1] >= GRID_HEIGHT):
            return True
        if head in self.body[1:]:
            return True
        return False

    def get_state(self):
        head = self.body[0]
        # This is a very simplified state representation for a basic agent
        # You can add more features for a more complex agent
        state = [
            # Danger straight
            (self.direction[0], self.direction[1]) in [(-1, 0), (1, 0), (0, -1), (0, 1)],
            # Danger right
            (self.direction[0], self.direction[1]) in [(0, 1), (0, -1), (1, 0), (-1, 0)],
            # Danger left
            (self.direction[0], self.direction[1]) in [(0, -1), (0, 1), (-1, 0), (1, 0)],
            # Food location
            self.food[0] < head[0],  # Food left
            self.food[0] > head[0],  # Food right
            self.food[1] < head[1],  # Food up
            self.food[1] > head[1]   # Food down
        ]
        return np.array(state, dtype=int)

# Define the Agent class (same as before)
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.epsilon = 1.0  # Start with high exploration
        self.epsilon_decay = 0.999
        self.epsilon_min = 0.01

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        # In a real DQN, this would be a neural network prediction
        # For our simple case, we will use a simple rule-based approach for demonstration
        # A more complex agent would have a neural network here
        return random.randrange(self.action_size)

# Main training loop
def train_agent():
    pygame.init()
    screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
    clock = pygame.time.Clock()

    state_size = 7
    action_size = 4
    agent = DQNAgent(state_size, action_size)

    episodes = 500  # Number of games to play
    for e in range(episodes):
        snake = Snake()
        state = snake.get_state()
        done = False
        while not done:
            action = agent.act(state)
            reward, done = snake.move(action)
            next_state = snake.get_state()

            # The agent would "remember" this and "replay" for training
            # We'll skip the complex learning part for this simplified example

            # Draw the game state for visual feedback
            screen.fill(BLACK)
            for x, y in snake.body:
                pygame.draw.rect(screen, GREEN, (x * GRID_SIZE, y * GRID_SIZE, GRID_SIZE, GRID_SIZE))
            pygame.draw.rect(screen, RED, (snake.food[0] * GRID_SIZE, snake.food[1] * GRID_SIZE, GRID_SIZE, GRID_SIZE))

            pygame.display.flip()
            clock.tick(10)

        # Print episode results
        print(f"Episode: {e+1}/{episodes}, Score: {snake.score}")

        # Decay epsilon to reduce exploration over time
        if agent.epsilon > agent.epsilon_min:
            agent.epsilon *= agent.epsilon_decay

    pygame.quit()

if __name__ == '__main__':
    train_agent()
# Out:
# Episode: 1/500, Score: 0
# Episode: 2/500, Score: 0
# Episode: 3/500, Score: 0
# Episode: 4/500, Score: 0
# Episode: 5/500, Score: 1
# Episode: 6/500, Score: 0
# Episode: 7/500, Score: 1
# Episode: 8/500, Score: 0
# Episode: 9/500, Score: 0
# Episode: 10/500, Score: 0
# Episode: 11/500, Score: 0
# Episode: 12/500, Score: 0
# Episode: 13/500, Score: 0
# Episode: 14/500, Score: 0
# Episode: 15/500, Score: 0
# Episode: 16/500, Score: 0
# Episode: 17/500, Score: 0
# Episode: 18/500, Score: 0
# Episode: 19/500, Score: 0
# Episode: 20/500, Score: 0
# Episode: 21/500, Score: 0
# Episode: 22/500, Score: 0
# Episode: 23/500, Score: 0
# Episode: 24/500, Score: 0
# Episode: 25/500, Score: 0
# Episode: 26/500, Score: 0
# Episode: 27/500, Score: 0
# Episode: 28/500, Score: 0
# Episode: 29/500, Score: 0
# Episode: 30/500, Score: 0
# Episode: 31/500, Score: 1
# Episode: 32/500, Score: 0
# Episode: 33/500, Score: 0
# Episode: 34/500, Score: 0
# Episode: 35/500, Score: 0
# Episode: 36/500, Score: 0
# Episode: 37/500, Score: 0
# Episode: 38/500, Score: 0
# Episode: 39/500, Score: 0
# Episode: 40/500, Score: 0
# Episode: 41/500, Score: 0
# Episode: 42/500, Score: 0
# Episode: 43/500, Score: 0
# Episode: 44/500, Score: 0
# Episode: 45/500, Score: 0
# Episode: 46/500, Score: 2
# Episode: 47/500, Score: 0
# Episode: 48/500, Score: 2
# Episode: 49/500, Score: 0
# Episode: 50/500, Score: 0
# Episode: 51/500, Score: 0
# Episode: 52/500, Score: 0
# Episode: 53/500, Score: 0
# Episode: 54/500, Score: 0
# Episode: 55/500, Score: 0
# Episode: 56/500, Score: 0
# Episode: 57/500, Score: 1
# Episode: 58/500, Score: 0
# Episode: 59/500, Score: 0
# Episode: 60/500, Score: 1
# Episode: 61/500, Score: 0
# Episode: 62/500, Score: 0
# Episode: 63/500, Score: 0
# Episode: 64/500, Score: 0
# Episode: 65/500, Score: 0
# Episode: 66/500, Score: 0
# Episode: 67/500, Score: 0
# Episode: 68/500, Score: 2
# Episode: 69/500, Score: 0
# Episode: 70/500, Score: 0
# Episode: 71/500, Score: 0
# Episode: 72/500, Score: 0
# Episode: 73/500, Score: 0
# Episode: 74/500, Score: 0
# Episode: 75/500, Score: 0
# Episode: 76/500, Score: 0
# Episode: 77/500, Score: 0
# Episode: 78/500, Score: 0
# Episode: 79/500, Score: 0
# Episode: 80/500, Score: 0
# Episode: 81/500, Score: 1
# Episode: 82/500, Score: 0
# Episode: 83/500, Score: 0
# Episode: 84/500, Score: 1
# Episode: 85/500, Score: 0
# Episode: 86/500, Score: 0
# Episode: 87/500, Score: 0
# Episode: 88/500, Score: 0
# Episode: 89/500, Score: 0
# Episode: 90/500, Score: 0
# Episode: 91/500, Score: 0
# Episode: 92/500, Score: 0
# Episode: 93/500, Score: 0
# Episode: 94/500, Score: 0
# Episode: 95/500, Score: 0
# Episode: 96/500, Score: 0
# Episode: 97/500, Score: 0
# Episode: 98/500, Score: 0
# Episode: 99/500, Score: 0
# Episode: 100/500, Score: 0
# Episode: 101/500, Score: 1
# Episode: 102/500, Score: 0
# Episode: 103/500, Score: 0
# Episode: 104/500, Score: 1
# Episode: 105/500, Score: 1
# Episode: 106/500, Score: 0
# Episode: 107/500, Score: 0
# Episode: 108/500, Score: 0
# Episode: 109/500, Score: 0
# Episode: 110/500, Score: 0
# Episode: 111/500, Score: 0
# Episode: 112/500, Score: 0
# Episode: 113/500, Score: 0
# Episode: 114/500, Score: 0
# Episode: 115/500, Score: 0
# Episode: 116/500, Score: 0
# Episode: 117/500, Score: 0
# Episode: 118/500, Score: 0
# Episode: 119/500, Score: 0
# Episode: 120/500, Score: 1
# Episode: 121/500, Score: 0
# Episode: 122/500, Score: 0
# Episode: 123/500, Score: 0
# Episode: 124/500, Score: 0
# Episode: 125/500, Score: 0
# Episode: 126/500, Score: 0
# Episode: 127/500, Score: 0
# Episode: 128/500, Score: 0
# Episode: 129/500, Score: 0
# Episode: 130/500, Score: 0
# Episode: 131/500, Score: 0
# Episode: 132/500, Score: 0
# Episode: 133/500, Score: 0
# Episode: 134/500, Score: 0
# Episode: 135/500, Score: 1
# Episode: 136/500, Score: 0
# Episode: 137/500, Score: 0
# Episode: 138/500, Score: 0
# Episode: 139/500, Score: 0
# Episode: 140/500, Score: 0
# Episode: 141/500, Score: 0
# Episode: 142/500, Score: 0
# Episode: 143/500, Score: 0
# Episode: 144/500, Score: 1
# Episode: 145/500, Score: 0
# Episode: 146/500, Score: 1
# Episode: 147/500, Score: 2
# Episode: 148/500, Score: 0
# Episode: 149/500, Score: 0
# Episode: 150/500, Score: 0
# Episode: 151/500, Score: 0
# Episode: 152/500, Score: 0
# Episode: 153/500, Score: 0
# Episode: 154/500, Score: 0
# Episode: 155/500, Score: 0
# Episode: 156/500, Score: 0
# Episode: 157/500, Score: 0
# Episode: 158/500, Score: 2
# Episode: 159/500, Score: 0
# Episode: 160/500, Score: 0
# Episode: 161/500, Score: 0
# Episode: 162/500, Score: 0
# Episode: 163/500, Score: 0
# Episode: 164/500, Score: 0
# Episode: 165/500, Score: 0
# Episode: 166/500, Score: 0
# Episode: 167/500, Score: 0
# Episode: 168/500, Score: 0
# Episode: 169/500, Score: 0
# Episode: 170/500, Score: 0
# Episode: 171/500, Score: 1
# Episode: 172/500, Score: 1
# Episode: 173/500, Score: 0
# Episode: 174/500, Score: 0
# Episode: 175/500, Score: 0
# Episode: 176/500, Score: 0
# Episode: 177/500, Score: 1
# Episode: 178/500, Score: 0
# Episode: 179/500, Score: 0
# Episode: 180/500, Score: 0
# Episode: 181/500, Score: 0
# Episode: 182/500, Score: 0
# Episode: 183/500, Score: 1
# Episode: 184/500, Score: 1
# Episode: 185/500, Score: 0
# Episode: 186/500, Score: 0
# Episode: 187/500, Score: 0
# Episode: 188/500, Score: 0
# Episode: 189/500, Score: 0
# Episode: 190/500, Score: 0
# Episode: 191/500, Score: 0
# Episode: 192/500, Score: 1
# Episode: 193/500, Score: 0
# Episode: 194/500, Score: 0
# Episode: 195/500, Score: 0
# Episode: 196/500, Score: 0
# Episode: 197/500, Score: 0
# Episode: 198/500, Score: 0
# Episode: 199/500, Score: 0
# Episode: 200/500, Score: 0
# Episode: 201/500, Score: 0
# Episode: 202/500, Score: 0
# Episode: 203/500, Score: 0
# Episode: 204/500, Score: 1
# Episode: 205/500, Score: 0
# Episode: 206/500, Score: 0
# Episode: 207/500, Score: 0
# Episode: 208/500, Score: 0
# Episode: 209/500, Score: 0
# Episode: 210/500, Score: 0
# Episode: 211/500, Score: 0
# Episode: 212/500, Score: 0
# Episode: 213/500, Score: 0
# Episode: 214/500, Score: 0
# Episode: 215/500, Score: 0
# Episode: 216/500, Score: 0
# Episode: 217/500, Score: 0
# Episode: 218/500, Score: 0
# Episode: 219/500, Score: 0
# Episode: 220/500, Score: 0
# Episode: 221/500, Score: 0
# Episode: 222/500, Score: 0
# Episode: 223/500, Score: 0
# Episode: 224/500, Score: 0
# Episode: 225/500, Score: 1
# Episode: 226/500, Score: 1
# Episode: 227/500, Score: 0
# Episode: 228/500, Score: 1
# Episode: 229/500, Score: 0
# Episode: 230/500, Score: 0
# Episode: 231/500, Score: 0
# Episode: 232/500, Score: 0
# Episode: 233/500, Score: 0
# Episode: 234/500, Score: 0
# Episode: 235/500, Score: 0
# Episode: 236/500, Score: 0
# Episode: 237/500, Score: 1
# Episode: 238/500, Score: 0
# Episode: 239/500, Score: 0
# Episode: 240/500, Score: 0
# Episode: 241/500, Score: 0
# Episode: 242/500, Score: 0
# Episode: 243/500, Score: 0
# Episode: 244/500, Score: 0
# Episode: 245/500, Score: 0
# Episode: 246/500, Score: 0
# Episode: 247/500, Score: 0
# Episode: 248/500, Score: 0
# Episode: 249/500, Score: 0
# Episode: 250/500, Score: 0
# Episode: 251/500, Score: 0
# Episode: 252/500, Score: 1
# Episode: 253/500, Score: 0
# Episode: 254/500, Score: 0
# Episode: 255/500, Score: 0
# Episode: 256/500, Score: 0
# Episode: 257/500, Score: 0
# Episode: 258/500, Score: 0
# Episode: 259/500, Score: 0
# Episode: 260/500, Score: 0
# Episode: 261/500, Score: 0
# Episode: 262/500, Score: 1
# Episode: 263/500, Score: 2
# Episode: 264/500, Score: 0
# Episode: 265/500, Score: 0
# Episode: 266/500, Score: 0
# Episode: 267/500, Score: 0
# Episode: 268/500, Score: 1
# Episode: 269/500, Score: 0
# Episode: 270/500, Score: 0
# Episode: 271/500, Score: 0
# Episode: 272/500, Score: 0
# Episode: 273/500, Score: 1
# Episode: 274/500, Score: 0
# Episode: 275/500, Score: 0
# Episode: 276/500, Score: 0
# Episode: 277/500, Score: 0
# Episode: 278/500, Score: 0
# Episode: 279/500, Score: 0
# Episode: 280/500, Score: 0
# Episode: 281/500, Score: 0
# Episode: 282/500, Score: 0
# Episode: 283/500, Score: 0
# Episode: 284/500, Score: 0
# Episode: 285/500, Score: 0
# Episode: 286/500, Score: 0
# Episode: 287/500, Score: 0
# Episode: 288/500, Score: 0
# Episode: 289/500, Score: 0
# Episode: 290/500, Score: 0
# Episode: 291/500, Score: 0
# Episode: 292/500, Score: 0
# Episode: 293/500, Score: 0
# Episode: 294/500, Score: 0
# Episode: 295/500, Score: 0
# Episode: 296/500, Score: 0
# Episode: 297/500, Score: 1
# Episode: 298/500, Score: 0
# Episode: 299/500, Score: 1
# Episode: 300/500, Score: 0
# Episode: 301/500, Score: 0
# Episode: 302/500, Score: 0
# Episode: 303/500, Score: 0
# Episode: 304/500, Score: 0
# Episode: 305/500, Score: 0
# Episode: 306/500, Score: 0
# Episode: 307/500, Score: 0
# Episode: 308/500, Score: 1
# Episode: 309/500, Score: 0
# Episode: 310/500, Score: 0
# Episode: 311/500, Score: 0
# Episode: 312/500, Score: 0
# Episode: 313/500, Score: 1
# Episode: 314/500, Score: 0
# Episode: 315/500, Score: 0
# Episode: 316/500, Score: 1
# Episode: 317/500, Score: 0
# Episode: 318/500, Score: 0
# Episode: 319/500, Score: 0
# Episode: 320/500, Score: 0
# Episode: 321/500, Score: 0
# Episode: 322/500, Score: 0
# Episode: 323/500, Score: 0
# Episode: 324/500, Score: 0
# Episode: 325/500, Score: 0
# Episode: 326/500, Score: 0
# Episode: 327/500, Score: 0
# Episode: 328/500, Score: 0
# Episode: 329/500, Score: 0
# Episode: 330/500, Score: 1
# Episode: 331/500, Score: 0
# Episode: 332/500, Score: 0
# Episode: 333/500, Score: 0
# Episode: 334/500, Score: 0
# Episode: 335/500, Score: 0
# Episode: 336/500, Score: 0
# Episode: 337/500, Score: 0
# Episode: 338/500, Score: 0
# Episode: 339/500, Score: 0
# Episode: 340/500, Score: 0
# Episode: 341/500, Score: 0
# Episode: 342/500, Score: 1
# Episode: 343/500, Score: 1
# Episode: 344/500, Score: 0
# Episode: 345/500, Score: 0
# Episode: 346/500, Score: 0
# Episode: 347/500, Score: 0
# Episode: 348/500, Score: 0
# Episode: 349/500, Score: 0
# Episode: 350/500, Score: 0
# Episode: 351/500, Score: 0
# Episode: 352/500, Score: 0
# Episode: 353/500, Score: 0
# Episode: 354/500, Score: 0
# Episode: 355/500, Score: 0
# Episode: 356/500, Score: 0
# Episode: 357/500, Score: 0
# Episode: 358/500, Score: 0
# Episode: 359/500, Score: 0
# Episode: 360/500, Score: 0
# Episode: 361/500, Score: 0
# Episode: 362/500, Score: 0
# Episode: 363/500, Score: 0
# Episode: 364/500, Score: 0
# Episode: 365/500, Score: 0
# Episode: 366/500, Score: 0
# Episode: 367/500, Score: 0
# Episode: 368/500, Score: 0
# Episode: 369/500, Score: 0
# Episode: 370/500, Score: 0
# Episode: 371/500, Score: 0
# Episode: 372/500, Score: 0
# Episode: 373/500, Score: 0
# Episode: 374/500, Score: 1
# Episode: 375/500, Score: 0
# Episode: 376/500, Score: 0
# Episode: 377/500, Score: 0
# Episode: 378/500, Score: 0
# Episode: 379/500, Score: 0
# Episode: 380/500, Score: 0
# Episode: 381/500, Score: 0
# Episode: 382/500, Score: 0
# Episode: 383/500, Score: 0
# Episode: 384/500, Score: 0
# Episode: 385/500, Score: 0
# Episode: 386/500, Score: 0
# Episode: 387/500, Score: 0
# Episode: 388/500, Score: 0
# Episode: 389/500, Score: 0
# Episode: 390/500, Score: 0
# Episode: 391/500, Score: 0
# Episode: 392/500, Score: 0
# Episode: 393/500, Score: 0
# Episode: 394/500, Score: 0
# Episode: 395/500, Score: 0
# Episode: 396/500, Score: 1
# Episode: 397/500, Score: 0
# Episode: 398/500, Score: 0
# Episode: 399/500, Score: 2
# Episode: 400/500, Score: 0
# Episode: 401/500, Score: 0
# Episode: 402/500, Score: 0
# Episode: 403/500, Score: 0
# Episode: 404/500, Score: 0
# Episode: 405/500, Score: 0
# Episode: 406/500, Score: 0
# Episode: 407/500, Score: 0
# Episode: 408/500, Score: 0
# Episode: 409/500, Score: 0
# Episode: 410/500, Score: 0
# Episode: 411/500, Score: 0
# Episode: 412/500, Score: 0
# Episode: 413/500, Score: 1
# Episode: 414/500, Score: 0
# Episode: 415/500, Score: 0
# Episode: 416/500, Score: 0
# Episode: 417/500, Score: 0
# Episode: 418/500, Score: 0
# Episode: 419/500, Score: 0
# Episode: 420/500, Score: 0
# Episode: 421/500, Score: 0
# Episode: 422/500, Score: 0
# Episode: 423/500, Score: 0
# Episode: 424/500, Score: 0
# Episode: 425/500, Score: 1
# Episode: 426/500, Score: 0
# Episode: 427/500, Score: 0
# Episode: 428/500, Score: 0
# Episode: 429/500, Score: 1
# Episode: 430/500, Score: 0
# Episode: 431/500, Score: 0
# Episode: 432/500, Score: 0
# Episode: 433/500, Score: 0
# Episode: 434/500, Score: 0
# Episode: 435/500, Score: 0
# Episode: 436/500, Score: 0
# Episode: 437/500, Score: 0
# Episode: 438/500, Score: 1
# Episode: 439/500, Score: 0
# Episode: 440/500, Score: 0
# Episode: 441/500, Score: 0
# Episode: 442/500, Score: 0
# Episode: 443/500, Score: 0
# Episode: 444/500, Score: 0
# Episode: 445/500, Score: 0
# Episode: 446/500, Score: 0
# Episode: 447/500, Score: 1
# Episode: 448/500, Score: 0
# Episode: 449/500, Score: 0
# Episode: 450/500, Score: 0
# Episode: 451/500, Score: 0
# Episode: 452/500, Score: 0
# Episode: 453/500, Score: 0
# Episode: 454/500, Score: 0
# Episode: 455/500, Score: 0
# Episode: 456/500, Score: 0
# Episode: 457/500, Score: 0
# Episode: 458/500, Score: 0
# Episode: 459/500, Score: 0
# Episode: 460/500, Score: 0
# Episode: 461/500, Score: 1
# Episode: 462/500, Score: 0
# Episode: 463/500, Score: 0
# Episode: 464/500, Score: 0
# Episode: 465/500, Score: 0
# Episode: 466/500, Score: 0
# Episode: 467/500, Score: 0
# Episode: 468/500, Score: 0
# Episode: 469/500, Score: 0
# Episode: 470/500, Score: 0
# Episode: 471/500, Score: 0
# Episode: 472/500, Score: 0
# Episode: 473/500, Score: 0
# Episode: 474/500, Score: 1
# Episode: 475/500, Score: 0
# Episode: 476/500, Score: 1
# Episode: 477/500, Score: 0
# Episode: 478/500, Score: 0
# Episode: 479/500, Score: 0
# Episode: 480/500, Score: 0
# Episode: 481/500, Score: 0
# Episode: 482/500, Score: 0
# Episode: 483/500, Score: 0
# Episode: 484/500, Score: 0
# Episode: 485/500, Score: 0
# Episode: 486/500, Score: 0
# Episode: 487/500, Score: 0
# Episode: 488/500, Score: 1
# Episode: 489/500, Score: 0
# Episode: 490/500, Score: 0
# Episode: 491/500, Score: 0
# Episode: 492/500, Score: 0
# Episode: 493/500, Score: 0
# Episode: 494/500, Score: 1
# Episode: 495/500, Score: 0
# Episode: 496/500, Score: 1
# Episode: 497/500, Score: 0
# Episode: 498/500, Score: 0
# Episode: 499/500, Score: 0
# Episode: 500/500, Score: 0
